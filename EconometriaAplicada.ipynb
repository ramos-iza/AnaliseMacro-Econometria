# %% [markdown]
# <a href="https://colab.research.google.com/github/ramos-iza/AnaliseMacro-Econometria/blob/main/EconometriaAplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Análise Macro - Econometria Aplicada
